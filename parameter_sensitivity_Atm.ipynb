# %% [markdown]
# ## Script to quantify parameter sensitivity and interactions
# ##### NASA-GISS atmosphere example

# %% [markdown]
# ##### authenticate github every.single.time : gh-scoped-creds

# %%
# set up your environment
! mamba env update -f environment.yml

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from esem import gp_model
from esem.utils import get_random_params
from sklearn.metrics import mean_squared_error, r2_score
#from scipy import stats
import gpflow

from SALib.sample import fast_sampler
from SALib.analyze import fast

import gcsfs
# Out:
# 2023-05-05 18:20:53.265558: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-05 18:20:53.358364: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
def normalize(var):
    return (var-min(var))/(max(var)-min(var))

def unnormalize(norm_var,raw_var):
    return norm_var*np.array(max(raw_var)-min(raw_var)) + np.array(min(raw_var))

# %%
# Load Data
fs = gcsfs.GCSFileSystem()
mapper = fs.get_mapper("gs://leap-persistent/yiqioyang/testing/gcm551.zarr")
ds = xr.open_dataset(mapper, engine='zarr')

# %%
np.shape(ds.param_vals.values)
# Out:
# (45, 551)

# %%
# get parameter sets in dataframe
#ppe_params = pd.DataFrame(np.transpose(ds.param_vals.values))
ppe_params = ds.param_vals.values
num_params = len(ppe_params)

# %%
ppe_params = pd.DataFrame(np.transpose(ppe_params))

# %%
# get reponse metric 
netrad = ds.model_annout[0,:].values
olr = pd.DataFrame(ds.model_annout[9,:].values)

# %%
netrad
# Out:
# array([ 2.880e+00,  7.340e+00,  2.850e+00, -3.440e+00, -5.450e+00,
#        -1.201e+01, -1.381e+01,  2.310e+00, -3.330e+00, -9.620e+00,
#         7.750e+00, -2.210e+00, -1.064e+01, -1.972e+01, -6.180e+00,
#         1.400e+00, -5.570e+00, -1.514e+01, -1.610e+00, -1.584e+01,
#        -2.600e-01, -6.240e+00,  3.810e+00, -2.260e+01,  3.400e-01,
#        -7.900e-01, -1.691e+01, -3.390e+00,  4.810e+00, -1.132e+01,
#        -1.858e+01,  9.420e+00, -1.114e+01, -1.882e+01,  5.340e+00,
#         1.430e+00, -1.320e+00, -3.490e+00,  3.790e+00, -6.830e+00,
#        -4.490e+00, -1.678e+01, -1.217e+01,  6.870e+00,  1.120e+00,
#        -2.740e+00, -1.990e+00, -4.380e+00,  1.110e+00,  9.400e+00,
#         9.100e-01,  6.150e+00, -8.000e-02,  6.600e+00, -1.355e+01,
#        -1.496e+01,  5.470e+00, -3.800e-01, -1.419e+01, -3.800e+00,
#        -8.480e+00, -6.640e+00, -2.535e+01, -2.880e+00,  5.720e+00,
#        -4.600e+00, -2.650e+00,  6.200e+00, -7.300e-01,  3.570e+00,
#        -1.559e+01, -9.400e+00, -1.100e+01, -1.137e+01, -9.500e+00,
#         1.082e+01,  2.730e+00, -3.970e+00, -1.310e+00, -2.030e+00,
#        -5.060e+00,  3.100e+00, -1.026e+01,  1.401e+01,  2.020e+00,
#        -3.240e+00, -9.080e+00,  1.043e+01,  7.770e+00, -1.180e+01,
#         1.010e+00,  8.500e-01, -1.225e+01, -8.630e+00, -1.217e+01,
#         5.570e+00,  2.560e+00, -5.250e+00,  1.393e+01,  7.200e-01,
#         2.070e+00, -8.640e+00, -4.790e+00, -1.070e+00, -8.690e+00,
#        -2.720e+00,  1.680e+00,  6.140e+00, -5.280e+00, -7.940e+00,
#         3.090e+00, -8.760e+00,  9.680e+00,  7.800e+00, -1.610e+00,
#         8.270e+00,  4.500e+00,  2.320e+00, -4.070e+00, -1.450e+01,
#        -7.560e+00,  4.320e+00,  1.337e+01,  1.611e+01, -3.720e+00,
#        -1.025e+01, -2.900e+00, -1.065e+01, -2.536e+01, -1.323e+01,
#        -1.300e+00,  7.380e+00,  1.084e+01, -7.150e+00, -6.450e+00,
#        -5.840e+00,  1.028e+01,  9.100e+00,  2.790e+00,  2.560e+00,
#        -9.620e+00, -1.401e+01, -4.320e+00, -1.100e+01,  8.080e+00,
#         2.970e+00, -2.300e-01, -1.199e+01, -8.330e+00,  1.395e+01,
#        -1.090e+00, -1.043e+01, -7.980e+00, -1.019e+01, -5.060e+00,
#        -1.082e+01, -1.110e+00, -4.120e+00, -4.250e+00, -1.573e+01,
#        -6.980e+00,  7.240e+00,  6.870e+00, -3.660e+00, -9.710e+00,
#        -1.752e+01, -1.665e+01, -9.050e+00, -1.490e+01, -1.319e+01,
#        -5.410e+00,  2.020e+00, -7.670e+00, -1.703e+01, -1.288e+01,
#        -7.000e+00, -4.390e+00,  1.370e+00, -1.972e+01, -4.540e+00,
#         1.760e+00,  2.940e+00, -2.660e+00, -1.944e+01,  7.800e-01,
#        -2.056e+01], dtype=float32)

# %% [markdown]
# ### Train Gaussian Process Emulator

# %%
# Define kernel
kernel_linear = gpflow.kernels.Linear(active_dims=range(num_params),variance=1)
kernel_matern32 = gpflow.kernels.Matern32(active_dims=range(num_params), variance=1, lengthscales = np.tile(1,45))
kernel = kernel_linear + kernel_matern32

# %%
# Train    
var_raw = np.array(olr)
Y = normalize(var_raw)

n_test = 50 # number of ensemble members to test emulator

X_test, X_train = ppe_params[:n_test], ppe_params[n_test:]
y_test, y_train = Y[:n_test], Y[n_test:]

emulator = gp_model(X_train,y_train)
emulator.train()
# Out:
# WARNING: Using default kernel - be sure you understand the assumptions this implies. Consult e.g.  http://www.cs.toronto.edu/~duvenaud/cookbook/ for an excellent description of different kernel choices.
# 2023-05-04 21:05:03.717494: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.

# %%
# plot emulator validation
y_pred, y_pred_var = emulator.predict(X_test)
rms = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test,y_pred)

y_test_raw = unnormalize(y_test,var_raw)

plt.plot([min(y_test_raw),max(y_test_raw)],[min(y_test_raw),max(y_test_raw)],c='k',linestyle='--',label='1:1 line')
plt.scatter(y_test_raw,unnormalize(y_pred,var_raw))
plt.text(min(y_test_raw),max(y_test_raw)*0.95,'R2 = '+str(np.round(r2,3)),fontsize=8)
#plt.set_title(pfts[pft],fontsize = 10)

#plt.savefig('PFT_emulator_eval_GM-AM-LAI.png',dpi=200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 # plot emulator validation
# ----> 2 y_pred, y_pred_var = emulator.predict(X_test)
#       3 rms = mean_squared_error(y_test, y_pred, squared=False)
#       4 r2 = r2_score(y_test,y_pred)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/esem/emulator.py:98, in Emulator.predict(self, x, *args, **kwargs)
#      95     x = x.to_numpy()
#      97 # TODO: Add a warning if .train hasn't been called?
# ---> 98 mean, var = self._predict(x, *args, **kwargs)
#     100 return (self.training_data.wrap(mean, 'Emulated '),
#     101         self.training_data.wrap(var, 'Variance in emulated '))
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/esem/emulator.py:122, in Emulator._predict(self, x, *args, **kwargs)
#     104 """
#     105 The (internal) predict interface used by e.g., a sampler. It is still in tf but has been post-processed
#     106 to allow comparison with obs.
#    (...)
#     119 Emulated prediction and variance as either np.ndarray or tf.Tensor
#     120 """
#     121 with self.tf_device_context:
# --> 122     mean, var = self.model.predict(x, *args, **kwargs)
#     123 # Left un-nested for readability
#     124 return self.training_data.process_wrapper(mean, var)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/esem/model_adaptor.py:92, in GPFlowModel.predict(self, *args, **kwargs)
#      91 def predict(self, *args, **kwargs):
# ---> 92     return self.model.predict_y(*args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/models/model.py:220, in GPModel.predict_y(self, Xnew, full_cov, full_output_cov)
#     213 if full_cov or full_output_cov:
#     214     # See https://github.com/GPflow/GPflow/issues/1461
#     215     raise NotImplementedError(
#     216         "The predict_y method currently supports only the argument values full_cov=False"
#     217         " and full_output_cov=False"
#     218     )
# --> 220 f_mean, f_var = self.predict_f(Xnew, full_cov=full_cov, full_output_cov=full_output_cov)
#     221 return self.likelihood.predict_mean_and_var(f_mean, f_var)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/models/gpr.py:171, in GPR_with_posterior.predict_f(self, Xnew, full_cov, full_output_cov)
#     161 def predict_f(
#     162     self, Xnew: InputData, full_cov: bool = False, full_output_cov: bool = False
#     163 ) -> MeanAndVariance:
#     164     """
#     165     For backwards compatibility, GPR's predict_f uses the fused (no-cache)
#     166     computation, which is more efficient during training.
#    (...)
#     169         model.posterior().predict_f(Xnew, ...)
#     170     """
# --> 171     return self.posterior(posteriors.PrecomputeCacheType.NOCACHE).fused_predict_f(
#     172         Xnew, full_cov=full_cov, full_output_cov=full_output_cov
#     173     )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/posteriors.py:210, in AbstractPosterior.fused_predict_f(self, Xnew, full_cov, full_output_cov)
#     203 def fused_predict_f(
#     204     self, Xnew: TensorType, full_cov: bool = False, full_output_cov: bool = False
#     205 ) -> MeanAndVariance:
#     206     """
#     207     Computes predictive mean and (co)variance at Xnew, including mean_function
#     208     Does not make use of caching
#     209     """
# --> 210     mean, cov = self._conditional_fused(
#     211         Xnew, full_cov=full_cov, full_output_cov=full_output_cov
#     212     )
#     213     return self._add_mean_function(Xnew, mean), cov
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/posteriors.py:398, in GPRPosterior._conditional_fused(self, Xnew, full_cov, full_output_cov)
#     395 err = self.Y_data - self.mean_function(self.X_data)
#     397 Kmm = self.kernel(self.X_data)
# --> 398 Knn = self.kernel(Xnew, full_cov=full_cov)
#     399 Kmn = self.kernel(self.X_data, Xnew)
#     400 Kmm_plus_s = add_noise_cov(Kmm, self.likelihood_variance)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/kernels/base.py:262, in ReducingCombination.__call__(self, X, X2, full_cov, presliced)
#     253 def __call__(
#     254     self,
#     255     X: TensorType,
#    (...)
#     259     presliced: bool = False,
#     260 ) -> tf.Tensor:
#     261     return self._reduce(
# --> 262         [k(X, X2, full_cov=full_cov, presliced=presliced) for k in self.kernels]
#     263     )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/kernels/base.py:262, in <listcomp>(.0)
#     253 def __call__(
#     254     self,
#     255     X: TensorType,
#    (...)
#     259     presliced: bool = False,
#     260 ) -> tf.Tensor:
#     261     return self._reduce(
# --> 262         [k(X, X2, full_cov=full_cov, presliced=presliced) for k in self.kernels]
#     263     )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/kernels/base.py:186, in Kernel.__call__(self, X, X2, full_cov, presliced)
#     184 if not full_cov:
#     185     assert X2 is None
# --> 186     return self.K_diag(X)
#     188 else:
#     189     return self.K(X, X2)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/gpflow/kernels/linears.py:62, in Linear.K_diag(self, X)
#      61 def K_diag(self, X: TensorType) -> tf.Tensor:
# ---> 62     return tf.reduce_sum(tf.square(X) * self.variance, axis=-1)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow_probability/python/util/deferred_tensor.py:83, in _tensorize(d, dtype, name, as_ref)
#      81 def _tensorize(d, dtype=None, name=None, as_ref=False):
#      82   """Tensor conversion function presuming `hasattr(d, '_value')`."""
# ---> 83   return d._value(dtype, name, as_ref)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow_probability/python/util/deferred_tensor.py:371, in DeferredTensor._value(self, dtype, name, as_ref)
#     367 if not tensorshape_util.is_compatible_with(y.shape, self.shape):
#     368   raise TypeError(
#     369       'Actual shape ({}) is incompatible with deferred shape ({}).'.format(
#     370           y.shape, self.shape))
# --> 371 return tf.convert_to_tensor(y, dtype=dtype, name=name)
#
# ValueError: Tensor conversion requested dtype float32 for Tensor with dtype float64: <tf.Tensor: shape=(), dtype=float64, numpy=0.008307172142355922>

# %% [markdown]
# ### One-at-a-time Sensitivity

# %%
n=21
s = np.linspace(0,1,n)
unif = pd.concat([pd.DataFrame(np.tile(0.5,n))]*num_params,axis=1) # hold all parameters at median value
unif.columns = ppe_params.columns
#unif['leafcn'] = np.tile(0.8,n) # change individual parameter default setting for OAAT

# %%
plt.figure(figsize=[14,12])

sample = unif
for i, p in enumerate(ppe_params.columns):
    
    ax=plt.subplot(7,5,i+1)
    sample[p] = s
    oaat, v = emulator.predict(sample)
    sd = v**0.5
    sample[p] = np.tile(0.5,n) # set column back to median
    ax.fill_between(s, oaat-sd, oaat+sd,color='forestgreen',alpha=0.4) # shade three standard deviations
    ax.plot(s,oaat,c='forestgreen',label='NL')
    
    plt.text(0,0.9,p)
    #plt.plot([0,1],[default, default],'--',c='k')
    ax.set_ylim([0,1])
    #if i == 15:
    #    plt.ylabel('Global mean annual mean PFT LAI (normalized)',fontsize=12)
    
#plt.savefig('param_sens/OAAT_sensitivity_PFT1-4-13_gmLAI.png',dpi=200)

# %% [markdown]
# ### Pairwise interactions

# %%
# pairwise interactions

fig = plt.figure(figsize=[16,16])
plt.rcParams.update({'font.size': 16})

param_list = ['leafcn','kmax','jmaxb0']

n=21
s = np.linspace(0,1,n)

pft = 1
ix = 1
for i, ip in enumerate(param_list):
    
    for j, jp in enumerate(param_list):
        
        if j>i :
            ix = ix+1
        else:

            ax =plt.subplot(3,3,ix)
            out = np.empty((n,n))
            for m in range(n):
                unif = pd.concat([pd.DataFrame(np.tile(0.5,n))]*num_params,axis=1) # hold all parameters at median value
                unif.columns = ppe_params.columns
                unif[ip] = np.tile(s[m],n)
                unif[jp] = s

                vals, _ = emulator_dict[pft].predict(unif)

                out[m,:] = vals

            contours = ax.contourf(s, s, out, 9, vmin=0.1, vmax=0.6)
            ax.set_xlabel(jp)
            ax.set_ylabel(ip)
            ix = ix+1
            

#fig.colorbar(contours,label='Leaf Area Index',pad = 0.2)
#fig.subplots_adjust(right=0.6)
#cbar_ax = fig.add_axes([0.66, 0.25, 0.05, 0.5])
#fig.colorbar(contours, cax=cbar_ax,label='Leaf Area Index')

plt.tight_layout()
#plt.savefig('test_

# %% [markdown]
# ### Fourier Amplitude Sensitivity

# %%
# fourier amplitude sensitivity test w/emulator
problem = {
    'names': ppe_params.columns,
    'num_vars': num_params,
    'bounds': [[0, 1]],
}

sample = fast_sampler.sample(problem, 1000, M=4, seed=None)

pft = 1
Y, _ = emulator_dict[pft].predict(sample)
FAST = fast.analyze(problem, Y, M=4, num_resamples=100, conf_level=0.95, print_to_console=False, seed=None)
sens = pd.DataFrame.from_dict(FAST)
sens.index = sens.names
df_sens = sens.sort_values(by=['S1'],ascending=False)

# %%
plt.figure(num=None, figsize=(12, 6), dpi=100, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 12})

ax = plt.subplot(1,1,1)
ax.bar(df_sens.names,df_sens['ST'],color='lightgrey',label='interactions')
ax.bar(df_sens.names,df_sens['S1'],color='darkolivegreen',label='main effects')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.legend(loc='upper right')
plt.ylabel('Proportion of total emulated variance (total=1)')
plt.title(str(pfts[pft])+' LAI')
plt.tight_layout()

# %% [markdown]
# ### FAST analysis for all PFTs

# %%
problem = {
    'names': ppe_params.columns,
    'num_vars': num_params,
    'bounds': [[0, 1]],
}

sample = fast_sampler.sample(problem, 1000, M=4, seed=None)

# %%
for pft in range(1,17):
    Y, _ = emulator_dict[pft].predict(sample)
    FAST = fast.analyze(problem, Y, M=4, num_resamples=100, conf_level=0.95, print_to_console=False, seed=None)
    if pft ==1:
        FAST_sens = pd.DataFrame.from_dict(FAST['S1'])
    else:
        FAST_sens[pft] = FAST['S1']
        
FAST_sens.index = pd.DataFrame.from_dict(FAST).names
FAST_sens.columns = pfts[1:17]

# %%
# heatmap of all global mean variables
params = ['jmaxb0', 'jmaxb1', 'leafcn', 'wc2wjb0', 'medlynintercept', 'medlynslope', 'kcha', 'tpu25ratio', 'tpuse_sf', 'theta_cj',
          'kmax', 'krmax', 'psi50', 'fstor2tran','crit_dayl', 'froot_leaf', 'nstem', 'slatop','leaf_long', 'stem_leaf', 'soilpsi_off',
          'grperc', 'lmr_intercept_atkin', 'lmrha', 'lmrhd', 'q10_mr', 'FUN_fracfixers', 'KCN', 'a_fix', 'fff', 'd_max', 'sucsat_sf']

FAST_sens = FAST_sens.reindex(params)

var_names = FAST_sens.columns
plt.figure(num=None, figsize=(12, 6), dpi=100, facecolor='w', edgecolor='k')
ax = plt.subplot(1,1,1)
im = ax.imshow(FAST_sens.transpose(),cmap='magma_r',vmin=0,vmax=0.25)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(params)), labels=params)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.set_yticks(np.arange(len(var_names)), labels=var_names)

cbar = plt.colorbar(im)
cbar.set_label("Relative influence on ensemble variance")
plt.tight_layout()
#plt.savefig('../figs/param_sens/FAST_sensitivity_GM-AM-LAI-PFT_heatmap.png',dpi=200)
